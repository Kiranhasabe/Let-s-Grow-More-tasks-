# %% [markdown]
# # Lets Grow More (LGMVIP)

# %% [markdown]
# #  Task 1: IRIS FLOWER CLASSIFICATION

# %% [markdown]
# # Name : Kiran Hasabe

# %% [markdown]
# Iris flower has three species; setosa, versicolor, and virginica, which differs according to their measurements. Now assume that you have the measurements of the iris flowers according to their species, and here your task is to train a machine learning model that can learn from the measurements of the iris species and classify them.

# %% [markdown]
# # Import all the required libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %% [markdown]
# # Import Data set

# %%
data=pd.read_csv(r"C:\Downloads\Iris data.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# # Exploring data

# %%
data.shape
# Out:
# (150, 6)

# %%
data.size
# Out:
# 900

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# # Obtaining Description/Summary Dataframe

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# # Taking required numerical data into anoter dataframe

# %%
data_df=data[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]  #choosing ftures having numerical data
data_df.sample(5) #viewing random 5 records from dataset
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 45             4.8           3.0            1.4           0.3
# 138            6.0           3.0            4.8           1.8
# 123            6.3           2.7            4.9           1.8
# 52             6.9           3.1            4.9           1.5
# 129            7.2           3.0            5.8           1.6

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# # Pair plot

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(20,8))
sns.barplot(data['SepalLengthCm'],data['SepalWidthCm'])
plt.show()
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
m=data.drop(['Id'],axis=1)
plt.figure(figsize=(10,10))
sns.pairplot(m,hue='Species',size=3)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [raw]
# From the above pairplotit shows that features of iris-Setosa are distinguishable from features of other categories

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
import seaborn as sns
sns.set(style="ticks")
sns.pairplot(data,hue="Species")

# %% [markdown]
# # Heat Map

# %% [raw]
# Heat Map allows you to visualize how storngy/weakly or positively/negatively the feature are correlated with light to dark colour & value of correlation coefficients

# %%
plt.figure(figsize=(8,8))
corre=data_df.corr()
sns.heatmap(corre,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Violion Plot

# %%
plt.figure(figsize=(8,8))
sns.violinplot(y='PetalLengthCm',x='Species',data=m)
plt.show()

plt.figure(figsize=(8,8))
sns.violinplot(y='PetalWidthCm',x='Species',data=m)
plt.show()

plt.figure(figsize=(8,8))
sns.violinplot(y='SepalLengthCm',x='Species',data=m)
plt.show()

plt.figure(figsize=(8,8))
sns.violinplot(y='SepalWidthCm',x='Species',data=m)
plt.show()

# %% [markdown]
# # Building the model

# %%
X= data.iloc[:,0:4]
X
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0      1            5.1           3.5            1.4
# 1      2            4.9           3.0            1.4
# 2      3            4.7           3.2            1.3
# 3      4            4.6           3.1            1.5
# 4      5            5.0           3.6            1.4
# ..   ...            ...           ...            ...
# 145  146            6.7           3.0            5.2
# 146  147            6.3           2.5            5.0
# 147  148            6.5           3.0            5.2
# 148  149            6.2           3.4            5.4
# 149  150            5.9           3.0            5.1
#
# [150 rows x 4 columns]

# %%
Y = data.iloc[:,-1]
Y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.24,random_state=20)

# %%
Y_train.head()
# Out:
# 85     Iris-versicolor
# 1          Iris-setosa
# 51     Iris-versicolor
# 130     Iris-virginica
# 55     Iris-versicolor
# Name: Species, dtype: object

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
type
#        [-1.01141719, -1.28523415,  0.02172942, -1.21362036],
#        [-0.32304967, -1.0430578 , -2.45542391, -0.14460787],
#        [ 1.46670588,  0.16782396, -0.20346634,  0.58682172],
#        [ 1.55848821, -0.07435239, -0.87905361,  0.75561316],
#        [ 1.07663095, -0.31652874, -0.65385786,  0.64308553],
#        [ 0.66361044,  0.53108849, -0.4286621 ,  1.03693224],
#        [ 1.23725004,  0.65217667, -0.65385786,  1.03693224],
#        [ 0.64066486,  1.4997939 , -0.20346634,  1.20572368],
#        [ 0.18175318, -0.07435239, -0.87905361,  0.08044738],
#        [ 0.96190303,  0.77326484, -0.20346634,  0.98066842],
#        [ 1.39786913,  2.22632295, -0.20346634,  1.31825131],
#        [ 0.80128394,  1.62088207,  1.1477082 ,  1.31825131],
#        [-1.51622003, -1.76958685, -0.4286621 , -1.32614799],
#        [ 0.8701207 ,  1.13652937, -0.20346634,  0.98066842],
#        [-1.08025394, -0.80088144,  0.92251244, -1.26988417],
#        [-1.60800237, -1.0430578 ,  1.1477082 , -1.32614799],
#        [-1.37854653, -0.07435239,  2.04849123, -1.43867562],
#        [ 1.62732497,  1.01544119, -0.20346634,  0.81187698],
#        [-0.50661434,  1.25761755,  0.02172942,  0.64308553],
#        [-0.09359383,  0.04673579,  0.24692517,  0.58682172],
#        [ 1.48965146,  1.25761755,  0.02172942,  0.92440461],
#        [ 1.12252212,  0.53108849, -0.87905361,  0.64308553],
#        [ 0.45710019, -0.31652874, -0.87905361,  0.24923883],
#        [-0.73607018, -1.76958685,  0.24692517, -1.3824118 ],
#        [ 1.21430446,  0.28891214, -0.20346634,  0.64308553],
#        [-0.94258044, -0.43761692,  2.49888274, -1.32614799],
#        [ 0.4341546 , -1.0430578 , -1.77983664, -0.2571355 ],
#        [ 0.98484862,  2.22632295,  1.59809971,  1.6558342 ],
#        [-1.14909069, -1.28523415,  0.69731669, -1.04482891],
#        [ 0.08997084,  0.16782396, -0.4286621 ,  0.41803027],
#        [-0.25421292,  0.28891214, -0.4286621 ,  0.5305579 ],
#        [ 1.19135887,  0.41000031, -0.65385786,  0.58682172],
#        [-0.66723343, -1.28523415, -0.20346634, -1.32614799],
#        [-1.03436277, -1.40632232,  0.24692517, -1.21362036],
#        [ 1.16841329,  1.62088207,  0.24692517,  1.2619875 ],
#        [ 1.60437938,  1.01544119,  0.47212093,  1.09319605],
#        [-0.34599525, -0.80088144, -0.87905361,  0.08044738],
#        [ 0.36531785, -0.43761692, -1.10424937,  0.36176646],
#        [ 0.11291643, -0.19544056, -1.10424937, -0.14460787],
#        [ 1.1454677 ,  1.01544119,  0.47212093,  1.09319605],
#        [ 1.51259705,  1.01544119,  0.02172942,  1.03693224],
#        [-0.7131246 , -1.0430578 ,  0.92251244, -1.21362036],
#        [ 1.05368537,  1.25761755,  0.24692517,  1.09319605],
#        [-1.30970978, -0.92196962,  0.92251244, -1.32614799],
#        [ 0.06702526,  1.01544119, -0.20346634,  0.69934935],
#        [-1.63094795, -1.5274105 ,  0.02172942, -1.26988417],
#        [-1.28676419, -0.19544056,  1.59809971, -1.15735654],
#        [ 1.65027055,  0.53108849, -1.32944513,  0.69934935],
#        [ 1.42081471,  0.53108849,  0.69731669,  1.03693224],
#        [ 0.75539278,  1.74197025, -0.4286621 ,  1.43077894],
#        [-1.47032887, -0.55870509,  1.37290396, -1.26988417],
#        [-0.96552602, -0.80088144,  2.27368699, -1.26988417],
#        [ 0.82422953,  0.77326484,  0.24692517,  0.75561316],
#        [ 0.20469876,  0.16782396, -0.87905361,  0.75561316],
#        [-0.30010408,  0.04673579, -0.20346634,  0.24923883],
#        [ 1.30608679,  2.4684993 ,  1.59809971,  1.48704276],
#        [-1.12614511, -1.0430578 , -0.20346634, -1.21362036],
#        [ 1.53554263,  1.25761755,  0.02172942,  0.75561316],
#        [-1.5621112 , -1.5274105 ,  0.69731669, -1.32614799],
#        [-1.53916562, -1.0430578 ,  0.69731669, -1.26988417],
#        [ 0.61771927, -0.07435239, -0.87905361,  0.75561316],
#        [ 0.70950161,  2.10523478, -0.20346634,  1.59957039],
#        [-1.33265536, -0.55870509,  1.82329547, -1.3824118 ],
#        [-1.10319952, -1.0430578 ,  0.69731669, -1.21362036],
#        [-0.78196135, -1.0430578 ,  0.92251244, -1.3824118 ],
#        [ 1.0077942 ,  2.22632295, -1.10424937,  1.76836183],
#        [-0.07064825,  0.28891214, -0.65385786,  0.1367112 ],
#        [-1.19498186, -1.5274105 ,  1.1477082 , -1.55120325],
#        [ 0.02113409,  0.89435302, -0.20346634,  0.36176646],
#        [ 1.4437603 ,  0.65217667,  0.02172942,  0.98066842],
#        [-1.35560095, -0.19544056,  2.94927426, -1.26988417],
#        [ 0.57182811, -0.19544056, -0.65385786,  0.19297501]])

# %%
X_test=scaler.fit_transform(X_test)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_test.shape)
print(Y_train.shape)
# Out:
# (114, 4)
# (36, 4)
# (36,)
# (114,)

# %%
# Creating a logestic regression model
model=LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
# Prediction
y_pred=model.predict(X_test)
y_pred
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor'],
#       dtype=object)

# %%
print(X_test.shape)
print(y_pred.shape)
# Out:
# (36, 4)
# (36,)

# %%
# Training accuracy
train_accuracy=model.score(X_train,Y_train)
print("The training accuracy is",train_accuracy)
# Out:
# The training accuracy is 0.9912280701754386

# %%
# Test accuracy
test_accuracy=model.score(X_test,Y_test)
print("The testing accuracy is",test_accuracy)
# Out:
# The testing accuracy is 0.9722222222222222

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
# Instantiate learning model (k = 3)
classifier = KNeighborsClassifier(n_neighbors=3)

# %%
# Fitting the model
classifier.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, y_pred)*100
print('Accuracy: ' + str(round(accuracy, 2)) + '%')
# Out:
# Accuracy: 97.22%

# %% [markdown]
# # Thank you...!!!
